# %%
# !unzip 10714284.zip
# Out:
# Archive:  10714284.zip
#  extracting: tingkai-li/early-prediction-varying-usage-data-V1.1.zip

# %%
# !unzip tingkai-li/early-prediction-varying-usage-data-V1.1.zip
# Out:
# Archive:  tingkai-li/early-prediction-varying-usage-data-V1.1.zip
# d1f55356b4bb56b92c81b92d623d76de70345257
#    creating: tingkai-li-early-prediction-varying-usage-data-d1f5535/
#   inflating: tingkai-li-early-prediction-varying-usage-data-d1f5535/Graphic_abstract.png
#   inflating: tingkai-li-early-prediction-varying-usage-data-d1f5535/LICENSE
#   inflating: tingkai-li-early-prediction-varying-usage-data-d1f5535/README.md
#    creating: tingkai-li-early-prediction-varying-usage-data-d1f5535/elastic_net_models/
#   inflating: tingkai-li-early-prediction-varying-usage-data-d1f5535/elastic_net_models/README.txt
#   inflating: tingkai-li-early-prediction-varying-usage-data-d1f5535/elastic_net_models/elastic_net_discharge_model.m
#   inflating: tingkai-li-early-prediction-varying-usage-data-d1f5535/elastic_net_models/elastic_net_main.m
#   inflating: tingkai-li-early-prediction-varying-usage-data-d1f5535/elastic_net_models/fit_dummy.m
# ...

# %%
# !unzip data/capacity_fade.zip
# !unzip data/Q_interpolated.zip
# !unzip data/RPT_json.zip
# Out:
# Archive:  data/capacity_fade.zip
#   inflating: capacity_fade/Release 1.0/G10C2.csv
#   inflating: capacity_fade/Release 1.0/G11C3.csv
#   inflating: capacity_fade/Release 1.0/G10C4.csv
#   inflating: capacity_fade/Release 1.0/G11C1.csv
#   inflating: capacity_fade/Release 1.0/G11C4.csv
#   inflating: capacity_fade/Release 1.0/G10C3.csv
#   inflating: capacity_fade/Release 1.0/G10C1.csv
#   inflating: capacity_fade/Release 1.0/G11C2.csv
#   inflating: capacity_fade/Release 1.0/G12C1.csv
#   inflating: capacity_fade/Release 1.0/G12C2.csv
#   inflating: capacity_fade/Release 1.0/G12C3.csv
#   inflating: capacity_fade/Release 1.0/G12C4.csv
#   inflating: capacity_fade/Release 1.0/G13C1.csv
#   inflating: capacity_fade/Release 1.0/G13C2.csv
#   inflating: capacity_fade/Release 1.0/G13C3.csv
#   inflating: capacity_fade/Release 1.0/G13C4.csv
#   inflating: capacity_fade/Release 1.0/G14C1.csv
#   inflating: capacity_fade/Release 1.0/G14C2.csv
# ...

# %%
# !unzip data/Cycling_json.zip
# Out:
# Archive:  data/Cycling_json.zip
#    creating: Cycling_json/Release 1.0/
#   inflating: Cycling_json/Release 1.0/G10C1.json
#   inflating: Cycling_json/Release 1.0/G10C2.json
#   inflating: Cycling_json/Release 1.0/G10C3.json
#   inflating: Cycling_json/Release 1.0/G10C4.json
#   inflating: Cycling_json/Release 1.0/G11C1.json
#   inflating: Cycling_json/Release 1.0/G11C2.json
#   inflating: Cycling_json/Release 1.0/G11C3.json
#   inflating: Cycling_json/Release 1.0/G11C4.json
#   inflating: Cycling_json/Release 1.0/G12C1.json
#   inflating: Cycling_json/Release 1.0/G12C2.json
#   inflating: Cycling_json/Release 1.0/G12C3.json
#   inflating: Cycling_json/Release 1.0/G12C4.json
#   inflating: Cycling_json/Release 1.0/G13C1.json
#   inflating: Cycling_json/Release 1.0/G13C2.json
#   inflating: Cycling_json/Release 1.0/G13C3.json
#   inflating: Cycling_json/Release 1.0/G13C4.json
#   inflating: Cycling_json/Release 1.0/G14C1.json
#   inflating: Cycling_json/Release 1.0/G14C2.json
# ...
